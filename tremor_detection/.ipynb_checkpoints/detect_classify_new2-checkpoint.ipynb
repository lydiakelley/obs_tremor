# %% [markdown]
# # **Detect and Classify Tremor from the IRIS Database**
# ---
# Workflow:
# - Imports
# - Inputs
# - Define Functions
# - Define Detect and Classify Function
# - Bin by Days
# - Apply Function & Process in Parallel
# - Concat Results & Save

# %% [markdown]
# ## Imports

# %%
import datetime
from obspy.clients.fdsn.client import Client
import obspy
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import dask
from dask.diagnostics import ProgressBar

#client = Client('IRIS')
import pickle
import os
import scipy.signal
import scipy.ndimage

from obspy.signal.trigger import classic_sta_lta
from obspy.signal.trigger import trigger_onset
from obspy import UTCDateTime
from obspy import Stream

from pnwstore.mseed import WaveformClient
from obspy import Stream
from datetime import timedelta


from obspy.clients.fdsn import Client
from datetime import timedelta, datetime

import logging
logging.basicConfig(level=logging.INFO)

print('done')
# Out:
# done

# %%
# gets data locally rather than online
client = WaveformClient()

# %% [markdown]
# ## Inputs
# Short Term Average & Long Term Average (STA/LTA) parameters

# %%
# Define step we want to chunk
step = 10 # seconds

# Define sta and lta window lengths
# Below chosen to optimize emergent signal detection!

sta_win = 10 # seconds, short term window
lta_win = 1000 # seconds, long term window

# %% [markdown]
# Time Endpoints and Station

# %%
t1 = obspy.UTCDateTime("2012-09-02T00:00:00.000")
t2 = obspy.UTCDateTime("2013-06-21T00:00:00.000")

network = '7D'
station = 'J09B' 
channel = 'BH2'
location = '*'

# Get response info for this station from IRIS
iris_client = Client('IRIS')
sta_response = iris_client.get_stations(network=network, station=station,starttime=t1,endtime=t2,level='response')
save_dir = 'classifications/'

# %% [markdown]
# ## Define Functions
# - Detect/Triggering: Check Data, Calculate STL/STA
# - Classify: Pick Peaks, Apply Gaussian, Ship Noise
# - Attach Response Cascadia
# - Waveform across Midnight

# %% [markdown]
# Check Data

# %%
def check_data(stream,t1,sr,step,data_time_length):
    
    data = stream[0].data
    data_sample_length = sr * data_time_length

    
    # Catch for if data stream is less than specified
    if len(data) < data_sample_length:
        data_sample_length = int(len(data) - (len(data)%(sr*step)))
        data_time_length = int(data_sample_length / sr)
        
    # Catch for if start time is not as specified
    if stream[0].stats.starttime != t1:
        t1 = stream[0].stats.starttime
    
    return(t1,data_time_length)

# %% [markdown]
# Calculate Short Term Average & Long Term Average (STL/STA)

# %%
def calc_stalta(data,sr,step,data_time_length,sta_win,lta_win):
    
    # Matricize the data as step s chunks
    data_sample_length = sr * data_time_length
    
    
    chunked = np.reshape(data[0:data_sample_length],[int(data_sample_length/(sr*step)),int(sr*step)])
    chunked_medians = [np.median(chunked[i,:]) for i in range(np.shape(chunked)[0])]
    chunked_times = np.linspace(0,data_time_length,len(chunked_medians))
    
    # Step through and calculate sta & lta every step s
    sta = []
    lta = []
    for i,vec in enumerate(chunked_medians):

        # STA is median of the next window
        nwin = int(sta_win / step)
        sta.append(np.median(chunked_medians[i:i+nwin]))


        # LTA is median of the past window
        nwin = int(lta_win / step)
        lta.append(np.median(chunked_medians[i-nwin:i]))
    
    stalta = np.array(sta)/np.array(lta)
    
    return(stalta,chunked_times)

# %% [markdown]
# Pick Peaks

# %%
def pick_peaks_welch(trace,sampling_rate,nperseg_multiple,microseism_cutoff=True):
    """
    Estimate power spectra of a trace using Welch's method
    Pick peaks within the spectra!
    
    INPUTS:
    trace = obspy object, waveform
    sampling_rate = sampling rate of trace
    nperseg_multiple = length of each segment used to construct the Welch spectrum
    microseism_cutoff = Bool, whether or not to cut off the lower end of the spectrum to avoid the microseism
    
    OUTPUTS:
    f = frequencies of the spectra
    Pxx_den = associated power at each frequency, in decibels
    peak_ind = index of peaks within the spectra (f and Pxx_den), if found
    peaks = picked peak object from scipy
    median_power = median power of spectra from 20-80 Hz in decibels
    """
    
    
    fs = sampling_rate
    x = trace.data
    nperseg = fs * nperseg_multiple
    
    f,Pxx_den = scipy.signal.welch(x,fs,nperseg=nperseg)
    if microseism_cutoff is True:
        f = f[4:]
        Pxx_den = Pxx_den[4:]
        
    Pxx_den = [10*np.log10(d) for d in Pxx_den]
    median_power = np.median(Pxx_den[20:80])
    
    peaks = scipy.signal.find_peaks(Pxx_den,threshold =median_power*5,prominence=10) 
    peak_ind = peaks[0]
    
    return(f,Pxx_den,peak_ind,peaks,median_power)

# %% [markdown]
# Apply Gaussian

# %%
def apply_gaussian(filtered_data,samp_rate,gaussian_width=5):
    """
    Smooth waveform using a gaussian window
    
    INPUTS
    filtered_data = filtered numpy array of seismic data (from an obspy trace)
    samp_rate = sampling rate of data
    gaussian width = width of Gaussian window in seconds
    
    OUTPUTS
    smoothed_window = smoothed numpy array of seismic data
    """
    
    # Square data
    data = filtered_data**2
    
    gaussian_radius = int((gaussian_width * samp_rate)/2)
    smoothed_window=scipy.ndimage.gaussian_filter1d(data,sigma=gaussian_radius/4,radius=gaussian_radius)
    
    return smoothed_window

# %% [markdown]
# Ship Noise

# %%
def ship_noise_classifier(trace,sampling_rate):
    """
    Check whether detection likely includes ship noise in the form of a spectral peak
    
    INPUTS
    trace = obspy trace object
    sampling_rate = sample rate of trace
    
    OUTPUTS
    ship_classifier = number of peaks in the spectra. If any exist, ship noise is likely!
    """
    
    
    # Pick peaks on the smoothed spectrum of the trace (nperseg multiple = 1)
    f,Pxx_den,peak_ind,peak_details,median_power = pick_peaks_welch(trace,sampling_rate,1,microseism_cutoff=True)
    
    if len(peak_ind)==0:
        ship_classifier = 0
    else:
        ship_classifier = len(peak_ind)

    
    return ship_classifier

# %%
# NOTE: SHOULDN'T NEED THIS ANYMORE
# PULL UP-TO-DATE STATION INFO FROM IRIS AT TOP OF NOTEBOOK

# def attach_response_cascadia(stream):
#     """
#     Reads in an obspy stream
#     Pulls down station response information for the corresponding station from where it is stored in Cascadia
#     Attaches this station response information to the stream, and returns the stream
#     """
    
#     # This is where station response information is stored on Cascadia, in xml format:
#     dir_base = '/1-fnp/pnwstore1/p-wd11/PNWStationXML/'
    
#     network = stream[0].stats.network
#     station = stream[0].stats.station
    
#     # Response file paths are in the format /1-fnp/pnwstore1/p-wd11/PNWStationXML/OO/OO.HYSB1.xml
#     response_file = dir_base+network+'/'+network+'.'+station+'.xml'

#     # Read response info using obspy
#     inventory = obspy.read_inventory(response_file)

#     # Attach response information to stream
#     stream.attach_response(inventory)
    
#     return stream

# %%
def get_waveform_across_midnight(client, network, station, location, channel, starttime, endtime):
    stream = Stream()
    current = starttime
    while current < endtime:
        end_of_day = obspy.UTCDateTime(current.date) + 86399  # 23:59:59
        chunk_end = min(end_of_day, endtime)
        #print(current, chunk_end)
        try:
            st_chunk = client.get_waveforms(
                network=network, station=station,
                location=location, channel=channel,
                starttime=current, endtime=chunk_end,
            )
            sr = round(st_chunk[0].stats.sampling_rate)
            st_chunk.resample(sr).merge(fill_value="interpolate")
            stream += st_chunk
        except Exception as e:
            print(f"Failed to get data from {current} to {chunk_end}: {e}")
        current = obspy.UTCDateTime(current.date + timedelta(days=1))
    return stream

# %% [markdown]
# ## Define Detect and Classify Function

# %%
def trigger_and_classify(t1, data_time_length, network, station, channel, sta_response, step, sta_win, lta_win, filepath):
    """
    Detects and classifies seismic events using STA/LTA and signal features.
    """
    
    # Adjust times with padding
    t1 = obspy.UTCDateTime(t1)
    t2 = t1 + data_time_length + 1000
    t1 = t1 - 1000

    try:
        client = WaveformClient() 

        # === 1. Detection ===
        st1 = get_waveform_across_midnight(client, network, station, "*", channel, t1, t2)
        st1.merge(fill_value= "interpolate")
        #print(f"Stream length: {len(st1)}")
        if len(st1) == 0:
            print(f"[{t1}] No traces found in stream. Skipping.")
            return [], []

        sr = round(st1[0].stats.sampling_rate)
        if st1[0].stats.sampling_rate != sr:
            st1.resample(sr).merge(fill_value="interpolate")
        st1.taper(0.05, max_length=5)
        st1.filter("bandpass", freqmin=3, freqmax=10)
        st1.trim(starttime=t1, endtime=t2)

        t1, data_time_length = check_data(st1, t1, sr, step, data_time_length)
        data = np.abs(st1[0].data)
        #print(f"Analyzing {st1[0].stats.station} {st1[0].stats.channel}")
        stalta, times = calc_stalta(data, sr, step, data_time_length, sta_win, lta_win)
        triggers = trigger_onset(stalta, 2, 1)
        ontimes = [t1 + times[tr[0]] for tr in triggers]
        offtimes = [t1 + times[tr[1]] for tr in triggers] 
        # Get rid of any detections less than 30 s
        keep_ind = []
        for j in range(len(ontimes)):
            if offtimes[j]-ontimes[j] > 30:
                keep_ind.append(j)
        ontimes = [ontimes[j] for j in keep_ind]
        offtimes = [offtimes[j] for j in keep_ind]
        # print(ontimes,offtimes)

        # === 2. Classification ===
        all_results = []

        for on, off in zip(ontimes, offtimes):
            #try:
            t1c, t2c = on, off

            # Ship noise classifier
            st_ship = get_waveform_across_midnight(client, network, station, "*", channel, t1c-5, t2c+5)
            st_ship.resample(sr).merge(fill_value="interpolate")
            # st_ship = attach_response_cascadia(st_ship)
            st_ship.attach_response(sta_response)
            st_ship[0].data = st_ship[0].data / st_ship[0].stats.response.instrument_sensitivity.value
            st_ship.trim(starttime=t1c, endtime=t2c)
            ship_classifier = ship_noise_classifier(st_ship[0], sr)

            # Waveform peak classifier
            st_wave = get_waveform_across_midnight(client, network, station, "*", channel, t1c-5, t2c+5)
            st_wave.resample(sr).merge(fill_value="interpolate")
            # st_wave = attach_response_cascadia(st_wave)
            st_wave.attach_response(sta_response)
            st_wave.filter("bandpass", freqmin=3, freqmax=10)
            st_wave.remove_response()
            st_wave.trim(starttime=t1c, endtime=t2c)
            max_amplitude = np.max(np.abs(st_wave[0].data))
            smoothed = apply_gaussian(st_wave[0].data, sr, gaussian_width=15)
            smoothed = smoothed / np.max(smoothed)
            peaks = scipy.signal.find_peaks(smoothed, prominence=0.1)
            num_waveform_peaks = len(peaks[0])

            # Welch frequency ratio
            t1w = t1c - 30
            t2w = t2c + 30
            st_welch = get_waveform_across_midnight(client, network, station, "*", channel, t1w-5, t2w+5)
            st_welch.resample(sr).merge(fill_value="interpolate")
            # st_welch = attach_response_cascadia(st_welch)
            st_welch.attach_response(sta_response)
            st_welch[0].data = st_welch[0].data / st_welch[0].stats.response.instrument_sensitivity.value
            st_welch.trim(starttime=t1w, endtime=t2w)
            f, Pxx_den, *_ = pick_peaks_welch(st_welch[0], sr, 5, microseism_cutoff=False)
            freq_ratio_welch = 10 ** (np.median(Pxx_den[25:50]) / 10) / 10 ** (np.median(Pxx_den[50:75]) / 10)

            # Save result
            all_results.append([
                (t1c, t2c), station, num_waveform_peaks,
                ship_classifier, freq_ratio_welch, max_amplitude
            ])

            #except Exception as e:
                #print(f"Classification failed for detection starting at {str(on)}: {e}")
                #continue

        # === Save all results ===
        # combined_file = filepath + station + "_all_detections.pickle"
        # with open(combined_file, "wb") as handle:
        #     pickle.dump(all_results, handle)

        return all_results

    except Exception as e:
        print(f"[{str(t1)}] No data or fatal error during detection/classification: {e}")
        return [], []

# %% [markdown]
# ## Bin data by days

# %%
time_bins = pd.date_range(start=t1.datetime, end=t2.datetime, freq='D')
data_time_length = 24 * 60 * 60
pickle_path = 'classifications/J09B_raw.pickle'

# %%
@dask.delayed
def loop_days(t, data_time_length, network, station, channel, sta_reseponse, step, sta_win, lta_win, filepath):
    t_utc = obspy.UTCDateTime(t)
    return trigger_and_classify(t_utc, data_time_length, network, station, channel, sta_response, step, sta_win, lta_win, filepath)

# Build lazy results list
lazy_results = [
    loop_days(t, data_time_length, network, station, channel, sta_response, step, sta_win, lta_win, save_dir)
    for t in time_bins
]

# Run Dask
with ProgressBar():
    results = dask.compute(*lazy_results)
# Out:
# [                                        ] | 0% Completed | 330.39 msFailed to get data from 2011-10-30T23:43:20.000000Z to 2011-10-30T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-31T00:00:00.000000Z to 2011-10-31T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-11-01T00:00:00.000000Z to 2011-11-01T00:16:40.000000Z: list index out of range
# [2011-10-30T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-08-16T23:43:20.000000Z to 2011-08-16T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-17T00:00:00.000000Z to 2011-08-17T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-09-01T23:43:20.000000Z to 2015-09-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-18T00:00:00.000000Z to 2011-08-18T00:16:40.000000Z: list index out of range
# [2011-08-16T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-09-02T00:00:00.000000Z to 2015-09-02T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-21T23:43:20.000000Z to 2011-10-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-09-03T00:00:00.000000Z to 2015-09-03T00:16:40.000000Z: list index out of range
# [2015-09-01T23:43:20.000000Z] No traces found in stream. Skipping.
# [                                        ] | 0% Completed | 436.12 msFailed to get data from 2011-10-22T00:00:00.000000Z to 2011-10-22T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-07-16T23:43:20.000000Z to 2011-07-16T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-07-17T00:00:00.000000Z to 2011-07-17T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-04-09T23:43:20.000000Z to 2015-04-09T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-08-04T23:43:20.000000Z to 2010-08-04T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2010-08-05T00:00:00.000000Z to 2010-08-05T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-08-12T23:43:20.000000Z to 2010-08-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-07-18T00:00:00.000000Z to 2011-07-18T00:16:40.000000Z: list index out of range
# [2011-07-16T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-03-05T23:43:20.000000Z to 2012-03-05T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-05-28T23:43:20.000000Z to 2011-05-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-04-10T00:00:00.000000Z to 2015-04-10T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-23T00:00:00.000000Z to 2011-10-23T00:16:40.000000Z: list index out of rangeFailed to get data from 2012-03-06T00:00:00.000000Z to 2012-03-06T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-08-06T00:00:00.000000Z to 2010-08-06T00:16:40.000000Z: list index out of range
# [2010-08-04T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2015-04-11T00:00:00.000000Z to 2015-04-11T00:16:40.000000Z: list index out of rangeFailed to get data from 2011-05-29T00:00:00.000000Z to 2011-05-29T23:59:59.000000Z: list index out of range
#
# [2015-04-09T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-07-10T23:43:20.000000Z to 2011-07-10T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-05T23:43:20.000000Z to 2011-03-05T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-02T23:43:20.000000Z to 2011-09-02T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-09T23:43:20.000000Z to 2010-01-09T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-08-13T00:00:00.000000Z to 2010-08-13T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-06-04T23:43:20.000000Z to 2011-06-04T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2011-09-03T00:00:00.000000Z to 2011-09-03T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-05-30T00:00:00.000000Z to 2011-05-30T00:16:40.000000Z: list index out of range
# [2011-10-21T23:43:20.000000Z] No traces found in stream. Skipping.[2011-05-28T23:43:20.000000Z] No traces found in stream. Skipping.Failed to get data from 2015-05-21T23:43:20.000000Z to 2015-05-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-14T23:43:20.000000Z to 2011-04-14T23:59:59.000000Z: list index out of range
#
#
# Failed to get data from 2010-08-14T00:00:00.000000Z to 2010-08-14T00:16:40.000000Z: list index out of range
# [2010-08-12T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-12-06T23:43:20.000000Z to 2011-12-06T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-10T00:00:00.000000Z to 2010-01-10T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-07-11T00:00:00.000000Z to 2011-07-11T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-03-06T00:00:00.000000Z to 2011-03-06T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-09-04T00:00:00.000000Z to 2011-09-04T00:16:40.000000Z: list index out of range
# [2011-09-02T23:43:20.000000Z] No traces found in stream. Skipping.
#
#
# Failed to get data from 2011-06-05T00:00:00.000000Z to 2011-06-05T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-04-15T00:00:00.000000Z to 2011-04-15T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-05-22T00:00:00.000000Z to 2015-05-22T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-02-08T23:43:20.000000Z to 2015-02-08T23:59:59.000000Z: list index out of range
#
#
# Failed to get data from 2012-03-07T00:00:00.000000Z to 2012-03-07T00:16:40.000000Z: list index out of range
# [2012-03-05T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-02-17T23:43:20.000000Z to 2010-02-17T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-06-30T23:43:20.000000Z to 2010-06-30T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-03-12T23:43:20.000000Z to 2010-03-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-12-07T00:00:00.000000Z to 2011-12-07T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-16T00:00:00.000000Z to 2011-04-16T00:16:40.000000Z: list index out of rangeFailed to get data from 2010-09-27T23:43:20.000000Z to 2010-09-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-11T00:00:00.000000Z to 2010-01-11T00:16:40.000000Z: list index out of rangeFailed to get data from 2011-05-13T23:43:20.000000Z to 2011-05-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-02-18T00:00:00.000000Z to 2010-02-18T23:59:59.000000Z: list index out of range
#
# [2010-01-09T23:43:20.000000Z] No traces found in stream. Skipping.
#
# [2011-04-14T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-02-09T00:00:00.000000Z to 2015-02-09T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-12-08T00:00:00.000000Z to 2011-12-08T00:16:40.000000Z: list index out of range
#
#
# [2011-12-06T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-06-06T00:00:00.000000Z to 2011-06-06T00:16:40.000000Z: list index out of range
# [2011-06-04T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-07-01T00:00:00.000000Z to 2010-07-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-07T00:00:00.000000Z to 2011-03-07T00:16:40.000000Z: list index out of range
# [2011-03-05T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-09-28T00:00:00.000000Z to 2010-09-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-02-19T00:00:00.000000Z to 2010-02-19T00:16:40.000000Z: list index out of range
# [2010-02-17T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-03-11T23:43:20.000000Z to 2011-03-11T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-03-13T00:00:00.000000Z to 2010-03-13T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-02-10T00:00:00.000000Z to 2015-02-10T00:16:40.000000Z: list index out of range
# [2015-02-08T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-07-02T00:00:00.000000Z to 2010-07-02T00:16:40.000000Z: list index out of rangeFailed to get data from 2015-05-23T00:00:00.000000Z to 2015-05-23T00:16:40.000000Z: list index out of range
# [2015-05-21T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-05-14T00:00:00.000000Z to 2011-05-14T23:59:59.000000Z: list index out of range
#
# [2010-06-30T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-09-29T00:00:00.000000Z to 2010-09-29T00:16:40.000000Z: list index out of range
#
# [2010-09-27T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-07-12T00:00:00.000000Z to 2011-07-12T00:16:40.000000Z: list index out of rangeFailed to get data from 2011-05-15T00:00:00.000000Z to 2011-05-15T00:16:40.000000Z: list index out of range
# [2011-07-10T23:43:20.000000Z] No traces found in stream. Skipping.
#
# [2011-05-13T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-03-12T00:00:00.000000Z to 2011-03-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-03-14T00:00:00.000000Z to 2010-03-14T00:16:40.000000Z: list index out of range
# [                                        ] | 0% Completed | 539.82 ms[2010-03-12T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-03-13T00:00:00.000000Z to 2011-03-13T00:16:40.000000Z: list index out of range
# [2011-03-11T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-03-01T23:43:20.000000Z to 2012-03-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-03-02T00:00:00.000000Z to 2012-03-02T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-03-03T00:00:00.000000Z to 2012-03-03T00:16:40.000000Z: list index out of range
# [2012-03-01T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-10-05T23:43:20.000000Z to 2010-10-05T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-10-06T00:00:00.000000Z to 2010-10-06T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-10-07T00:00:00.000000Z to 2010-10-07T00:16:40.000000Z: list index out of range
# [2010-10-05T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-04-11T23:43:20.000000Z to 2012-04-11T23:59:59.000000Z: list index out of range
# [                                        ] | 1% Completed | 644.39 msFailed to get data from 2012-04-12T00:00:00.000000Z to 2012-04-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-07-25T23:43:20.000000Z to 2010-07-25T23:59:59.000000Z: list index out of rangeFailed to get data from 2012-04-13T00:00:00.000000Z to 2012-04-13T00:16:40.000000Z: list index out of range
# [2012-04-11T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2011-03-17T23:43:20.000000Z to 2011-03-17T23:59:59.000000Z: list index out of rangeFailed to get data from 2010-07-26T00:00:00.000000Z to 2010-07-26T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2010-07-27T00:00:00.000000Z to 2010-07-27T00:16:40.000000Z: list index out of rangeFailed to get data from 2011-03-18T00:00:00.000000Z to 2011-03-18T23:59:59.000000Z: list index out of range
# [2010-07-25T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2011-03-19T00:00:00.000000Z to 2011-03-19T00:16:40.000000Z: list index out of range
# [2011-03-17T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-09-13T23:43:20.000000Z to 2011-09-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-14T00:00:00.000000Z to 2011-09-14T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-07-01T23:43:20.000000Z to 2015-07-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-07-02T00:00:00.000000Z to 2015-07-02T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-09-15T00:00:00.000000Z to 2011-09-15T00:16:40.000000Z: list index out of range
# [2011-09-13T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2015-07-03T00:00:00.000000Z to 2015-07-03T00:16:40.000000Z: list index out of range
# [2015-07-01T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-07-09T23:43:20.000000Z to 2015-07-09T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-10-23T23:43:20.000000Z to 2011-10-23T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-24T23:43:20.000000Z to 2012-02-24T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2010-08-19T23:43:20.000000Z to 2010-08-19T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-26T23:43:20.000000Z to 2012-02-26T23:59:59.000000Z: list index out of rangeFailed to get data from 2010-12-13T23:43:20.000000Z to 2010-12-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-25T00:00:00.000000Z to 2012-02-25T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-10-24T00:00:00.000000Z to 2011-10-24T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-07-10T00:00:00.000000Z to 2015-07-10T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2010-08-20T00:00:00.000000Z to 2010-08-20T23:59:59.000000Z: list index out of range
#
#
# Failed to get data from 2013-12-17T00:00:00.000000Z to 2013-12-17T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-27T00:00:00.000000Z to 2012-02-27T23:59:59.000000Z: list index out of rangeFailed to get data from 2010-08-21T00:00:00.000000Z to 2010-08-21T00:16:40.000000Z: list index out of rangeFailed to get data from 2010-12-14T00:00:00.000000Z to 2010-12-14T23:59:59.000000Z: list index out of range
# [2010-08-19T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2012-02-26T00:00:00.000000Z to 2012-02-26T00:16:40.000000Z: list index out of rangeFailed to get data from 2012-01-02T23:43:20.000000Z to 2012-01-02T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-06-09T23:43:20.000000Z to 2015-06-09T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-07-11T00:00:00.000000Z to 2015-07-11T00:16:40.000000Z: list index out of range
# [2015-07-09T23:43:20.000000Z] No traces found in stream. Skipping.
#
#
#
# [2012-02-24T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-10-25T00:00:00.000000Z to 2011-10-25T00:16:40.000000Z: list index out of range
# [2011-10-23T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2015-02-01T23:43:20.000000Z to 2015-02-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-06T23:43:20.000000Z to 2012-02-06T23:59:59.000000Z: list index out of rangeFailed to get data from 2012-02-28T00:00:00.000000Z to 2012-02-28T00:16:40.000000Z: list index out of range
# [2012-02-26T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-06-10T00:00:00.000000Z to 2015-06-10T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2012-01-03T00:00:00.000000Z to 2012-01-03T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-02-02T00:00:00.000000Z to 2015-02-02T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-06-11T00:00:00.000000Z to 2015-06-11T00:16:40.000000Z: list index out of rangeFailed to get data from 2012-02-07T00:00:00.000000Z to 2012-02-07T23:59:59.000000Z: list index out of range
#
#
# [2015-06-09T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-02-03T00:00:00.000000Z to 2015-02-03T00:16:40.000000Z: list index out of range
# [2015-02-01T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-02-24T23:43:20.000000Z to 2011-02-24T23:59:59.000000Z: list index out of rangeFailed to get data from 2015-04-30T23:43:20.000000Z to 2015-04-30T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2012-02-08T00:00:00.000000Z to 2012-02-08T00:16:40.000000Z: list index out of range
# [2012-02-06T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-01-04T00:00:00.000000Z to 2012-01-04T00:16:40.000000Z: list index out of rangeFailed to get data from 2015-04-28T23:43:20.000000Z to 2015-04-28T23:59:59.000000Z: list index out of range
# [2012-01-02T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-05-01T00:00:00.000000Z to 2015-05-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-07T23:43:20.000000Z to 2012-02-07T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-05-02T00:00:00.000000Z to 2015-05-02T00:16:40.000000Z: list index out of range
# [2015-04-30T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-02-25T00:00:00.000000Z to 2011-02-25T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2015-04-29T00:00:00.000000Z to 2015-04-29T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-08T00:00:00.000000Z to 2012-02-08T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-02-26T00:00:00.000000Z to 2011-02-26T00:16:40.000000Z: list index out of rangeFailed to get data from 2015-04-30T00:00:00.000000Z to 2015-04-30T00:16:40.000000Z: list index out of range
# [2015-04-28T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-02-09T00:00:00.000000Z to 2012-02-09T00:16:40.000000Z: list index out of range
# [2012-02-07T23:43:20.000000Z] No traces found in stream. Skipping.
#
# [2011-02-24T23:43:20.000000Z] No traces found in stream. Skipping.
# [                                        ] | 2% Completed | 747.46 msFailed to get data from 2015-02-15T23:43:20.000000Z to 2015-02-15T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-02-16T00:00:00.000000Z to 2015-02-16T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-02-17T00:00:00.000000Z to 2015-02-17T00:16:40.000000Z: list index out of range
# [2015-02-15T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2009-10-27T23:43:20.000000Z to 2009-10-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-10-28T00:00:00.000000Z to 2009-10-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-10-29T00:00:00.000000Z to 2009-10-29T00:16:40.000000Z: list index out of range
# [2009-10-27T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-02-18T23:43:20.000000Z to 2010-02-18T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-02-19T00:00:00.000000Z to 2010-02-19T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-02-20T00:00:00.000000Z to 2010-02-20T00:16:40.000000Z: list index out of range
# [2010-02-18T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-05-14T23:43:20.000000Z to 2010-05-14T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-05-15T00:00:00.000000Z to 2010-05-15T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-05-16T00:00:00.000000Z to 2010-05-16T00:16:40.000000Z: list index out of range
# [2010-05-14T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-09-28T23:43:20.000000Z to 2011-09-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-29T00:00:00.000000Z to 2011-09-29T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-30T00:00:00.000000Z to 2011-09-30T00:16:40.000000Z: list index out of range
# [2011-09-28T23:43:20.000000Z] No traces found in stream. Skipping.
# [                                        ] | 2% Completed | 854.26 msFailed to get data from 2011-07-18T23:43:20.000000Z to 2011-07-18T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-01-27T23:43:20.000000Z to 2012-01-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-14T23:43:20.000000Z to 2011-09-14T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-07-19T00:00:00.000000Z to 2011-07-19T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2011-09-15T00:00:00.000000Z to 2011-09-15T23:59:59.000000Z: list index out of rangeFailed to get data from 2012-01-28T00:00:00.000000Z to 2012-01-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-07-20T00:00:00.000000Z to 2011-07-20T00:16:40.000000Z: list index out of range
# [2011-07-18T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2010-01-20T23:43:20.000000Z to 2010-01-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-01-29T00:00:00.000000Z to 2012-01-29T00:16:40.000000Z: list index out of range
# [2012-01-27T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-01-21T00:00:00.000000Z to 2010-01-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-16T00:00:00.000000Z to 2011-09-16T00:16:40.000000Z: list index out of range
# [2011-09-14T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-01-22T00:00:00.000000Z to 2010-01-22T00:16:40.000000Z: list index out of range
# [2010-01-20T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-10-15T23:43:20.000000Z to 2011-10-15T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-16T00:00:00.000000Z to 2011-10-16T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-17T00:00:00.000000Z to 2011-10-17T00:16:40.000000Z: list index out of range
# [2011-10-15T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-12-15T00:00:00.000000Z to 2010-12-15T00:16:40.000000Z: list index out of range
# [2010-12-13T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-05-26T23:43:20.000000Z to 2012-05-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-27T00:00:00.000000Z to 2012-05-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-28T00:00:00.000000Z to 2012-05-28T00:16:40.000000Z: list index out of rangeFailed to get data from 2010-04-27T23:43:20.000000Z to 2010-04-27T23:59:59.000000Z: list index out of range
# [2012-05-26T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2011-07-03T23:43:20.000000Z to 2011-07-03T23:59:59.000000Z: list index out of rangeFailed to get data from 2010-04-28T00:00:00.000000Z to 2010-04-28T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2011-07-04T00:00:00.000000Z to 2011-07-04T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-07-05T00:00:00.000000Z to 2011-07-05T00:16:40.000000Z: list index out of range
# [2011-07-03T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-04-29T00:00:00.000000Z to 2010-04-29T00:16:40.000000Z: list index out of range
# [2010-04-27T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 2% Completed | 959.89 msFailed to get data from 2011-06-12T23:43:20.000000Z to 2011-06-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-06-13T00:00:00.000000Z to 2011-06-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-24T23:43:20.000000Z to 2012-05-24T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-06-14T00:00:00.000000Z to 2011-06-14T00:16:40.000000Z: list index out of range
# [2011-06-12T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2012-05-25T00:00:00.000000Z to 2012-05-25T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-26T00:00:00.000000Z to 2012-05-26T00:16:40.000000Z: list index out of range
# [2012-05-24T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-03-31T23:43:20.000000Z to 2015-03-31T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-04-01T00:00:00.000000Z to 2015-04-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-04-02T00:00:00.000000Z to 2015-04-02T00:16:40.000000Z: list index out of range
# [2015-03-31T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-04-12T23:43:20.000000Z to 2011-04-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-13T00:00:00.000000Z to 2011-04-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-14T00:00:00.000000Z to 2011-04-14T00:16:40.000000Z: list index out of range
# [2011-04-12T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2010-02-11T23:43:20.000000Z to 2010-02-11T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-09-13T23:43:20.000000Z to 2009-09-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-02-12T00:00:00.000000Z to 2010-02-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-09-14T00:00:00.000000Z to 2009-09-14T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-09-15T00:00:00.000000Z to 2009-09-15T00:16:40.000000Z: list index out of rangeFailed to get data from 2010-02-13T00:00:00.000000Z to 2010-02-13T00:16:40.000000Z: list index out of range
# [2010-02-11T23:43:20.000000Z] No traces found in stream. Skipping.
#
# [2009-09-13T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-03-07T23:43:20.000000Z to 2011-03-07T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-08T00:00:00.000000Z to 2011-03-08T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-09T00:00:00.000000Z to 2011-03-09T00:16:40.000000Z: list index out of range
# [2011-03-07T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 2.99 s
# /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/jupyter_share/miniconda3/envs/seismo/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# [#                                       ] | 3% Completed | 3.50 sFailed to get data from 2011-09-19T23:43:20.000000Z to 2011-09-19T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-20T00:00:00.000000Z to 2011-09-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-21T00:00:00.000000Z to 2011-09-21T00:16:40.000000Z: list index out of range
# [2011-09-19T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 5.78 sFailed to get data from 2013-10-05T23:43:20.000000Z to 2013-10-05T23:59:59.000000Z: list index out of range
# [#                                       ] | 3% Completed | 14.47 sFailed to get data from 2010-11-01T00:00:00.000000Z to 2010-11-01T00:16:40.000000Z: list index out of range
# [#                                       ] | 3% Completed | 17.76 s[2010-10-30T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 18.50 sFailed to get data from 2010-12-09T00:00:00.000000Z to 2010-12-09T00:16:40.000000Z: list index out of range
# [#                                       ] | 3% Completed | 32.71 sFailed to get data from 2010-11-18T00:00:00.000000Z to 2010-11-18T00:16:40.000000Z: list index out of range
# [#                                       ] | 3% Completed | 37.22 s[2010-12-07T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 37.76 sFailed to get data from 2011-04-30T23:43:20.000000Z to 2011-04-30T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-05-01T00:00:00.000000Z to 2011-05-01T23:59:59.000000Z: list index out of range
# [#                                       ] | 3% Completed | 38.00 sFailed to get data from 2011-05-02T00:00:00.000000Z to 2011-05-02T00:16:40.000000Z: list index out of range
# [2011-04-30T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 40.13 s[2010-11-03T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 43.83 sFailed to get data from 2012-07-13T00:00:00.000000Z to 2012-07-13T00:16:40.000000Z: list index out of range
# [#                                       ] | 3% Completed | 79.73 s[2012-10-13T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 80.94 s[2012-09-20T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 81.17 sFailed to get data from 2011-04-25T23:43:20.000000Z to 2011-04-25T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-26T00:00:00.000000Z to 2011-04-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-27T00:00:00.000000Z to 2011-04-27T00:16:40.000000Z: list index out of range
# [2011-04-25T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 83.53 s[2012-12-27T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 83.66 sFailed to get data from 2010-06-24T23:43:20.000000Z to 2010-06-24T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-06-25T00:00:00.000000Z to 2010-06-25T23:59:59.000000Z: list index out of range
# [#                                       ] | 3% Completed | 83.77 sFailed to get data from 2010-06-26T00:00:00.000000Z to 2010-06-26T00:16:40.000000Z: list index out of range
# [2010-06-24T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 85.11 s[2010-11-16T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 86.45 s[2012-09-07T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 86.58 sFailed to get data from 2011-06-26T23:43:20.000000Z to 2011-06-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-06-27T00:00:00.000000Z to 2011-06-27T23:59:59.000000Z: list index out of range
# [#                                       ] | 3% Completed | 86.71 s0:16:40.000000Z: list index out of range
# [2011-06-26T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 87.54 s[2012-07-11T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 87.80 sFailed to get data from 2011-10-20T23:43:20.000000Z to 2011-10-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-21T00:00:00.000000Z to 2011-10-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-22T00:00:00.000000Z to 2011-10-22T00:16:40.000000Z: list index out of range
# [2011-10-20T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 88.06 sFailed to get data from 2011-12-23T23:43:20.000000Z to 2011-12-23T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-12-24T00:00:00.000000Z to 2011-12-24T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-12-25T00:00:00.000000Z to 2011-12-25T00:16:40.000000Z: list index out of range
# [2011-12-23T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 88.29 sFailed to get data from 2011-08-08T23:43:20.000000Z to 2011-08-08T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-09T00:00:00.000000Z to 2011-08-09T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-10T00:00:00.000000Z to 2011-08-10T00:16:40.000000Z: list index out of range
# [2011-08-08T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 88.57 sFailed to get data from 2011-08-20T23:43:20.000000Z to 2011-08-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-21T00:00:00.000000Z to 2011-08-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-22T00:00:00.000000Z to 2011-08-22T00:16:40.000000Z: list index out of range
# [2011-08-20T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 88.80 sFailed to get data from 2015-07-05T23:43:20.000000Z to 2015-07-05T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-07-06T00:00:00.000000Z to 2015-07-06T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-07-07T00:00:00.000000Z to 2015-07-07T00:16:40.000000Z: list index out of range
# [2015-07-05T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 3% Completed | 92.29 s[2013-01-21T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 3% Completed | 93.41 s[2012-07-25T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 94.12 s[2012-11-05T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 95.37 s[2012-06-02T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 100.52 s[2012-11-18T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 102.45 s[2013-01-11T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 102.67 s[2012-06-05T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 111.36 s[2013-10-06T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 111.48 sFailed to get data from 2010-05-06T23:43:20.000000Z to 2010-05-06T23:59:59.000000Z: list index out of range
# [#                                       ] | 4% Completed | 111.60 s:59:59.000000Z: list index out of range
# Failed to get data from 2010-05-08T00:00:00.000000Z to 2010-05-08T00:16:40.000000Z: list index out of range
# [2010-05-06T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 116.21 s[2013-09-03T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 116.36 sFailed to get data from 2010-09-12T23:43:20.000000Z to 2010-09-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-09-13T00:00:00.000000Z to 2010-09-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-09-14T00:00:00.000000Z to 2010-09-14T00:16:40.000000Z: list index out of range
# [2010-09-12T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 116.47 sFailed to get data from 2009-09-30T23:43:20.000000Z to 2009-09-30T23:59:59.000000Z: list index out of range
# [#                                       ] | 4% Completed | 116.59 s:59:59.000000Z: list index out of range
# Failed to get data from 2009-10-02T00:00:00.000000Z to 2009-10-02T00:16:40.000000Z: list index out of range
# [2009-09-30T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 116.70 sFailed to get data from 2011-01-21T23:43:20.000000Z to 2011-01-21T23:59:59.000000Z: list index out of range
# [#                                       ] | 4% Completed | 116.83 sFailed to get data from 2011-01-22T00:00:00.000000Z to 2011-01-22T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-01-23T00:00:00.000000Z to 2011-01-23T00:16:40.000000Z: list index out of range
# [2011-01-21T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 119.55 s[2014-07-09T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 119.67 s[2013-09-26T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# Failed to get data from 2012-02-08T23:43:20.000000Z to 2012-02-08T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-09T00:00:00.000000Z to 2012-02-09T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-10T00:00:00.000000Z to 2012-02-10T00:16:40.000000Z: list index out of range
# [2012-02-08T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 119.80 s[2013-04-14T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 120.04 s[2013-08-09T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 122.80 s[2013-06-20T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 122.93 sFailed to get data from 2015-06-27T23:43:20.000000Z to 2015-06-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-06-28T00:00:00.000000Z to 2015-06-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-06-29T00:00:00.000000Z to 2015-06-29T00:16:40.000000Z: list index out of range
# [2015-06-27T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 123.16 s[2014-01-08T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 123.39 sFailed to get data from 2010-06-26T23:43:20.000000Z to 2010-06-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-06-27T00:00:00.000000Z to 2010-06-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-06-28T00:00:00.000000Z to 2010-06-28T00:16:40.000000Z: list index out of range
# [2010-06-26T23:43:20.000000Z] No traces found in stream. Skipping.
# [#                                       ] | 4% Completed | 123.75 s[2013-03-09T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [#                                       ] | 4% Completed | 124.23 s[2013-06-28T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [2014-09-07T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 124.67 s[2013-12-06T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 125.39 s[2014-03-16T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 125.80 s[2014-08-31T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 125.92 sFailed to get data from 2015-03-06T23:43:20.000000Z to 2015-03-06T23:59:59.000000Z: list index out of range
# [##                                      ] | 5% Completed | 126.04 s:59:59.000000Z: list index out of range
# Failed to get data from 2015-03-08T00:00:00.000000Z to 2015-03-08T00:16:40.000000Z: list index out of range
# [2015-03-06T23:43:20.000000Z] No traces found in stream. Skipping.
# [##                                      ] | 5% Completed | 126.15 s[2014-03-11T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 126.27 s[2014-10-26T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 126.38 sFailed to get data from 2009-10-22T23:43:20.000000Z to 2009-10-22T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-10-23T00:00:00.000000Z to 2009-10-23T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-10-24T00:00:00.000000Z to 2009-10-24T00:16:40.000000Z: list index out of range
# [2009-10-22T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2015-07-21T23:43:20.000000Z to 2015-07-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-07-22T00:00:00.000000Z to 2015-07-22T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-07-23T00:00:00.000000Z to 2015-07-23T00:16:40.000000Z: list index out of range
# [2015-07-21T23:43:20.000000Z] No traces found in stream. Skipping.
# [2014-09-06T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##                                      ] | 5% Completed | 126.50 s[2014-10-25T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# Failed to get data from 2010-07-27T23:43:20.000000Z to 2010-07-27T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-07-28T00:00:00.000000Z to 2010-07-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-07-29T00:00:00.000000Z to 2010-07-29T00:16:40.000000Z: list index out of range
# [2010-07-27T23:43:20.000000Z] No traces found in stream. Skipping.
# [##                                      ] | 5% Completed | 126.61 sn/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# Failed to get data from 2012-03-22T23:43:20.000000Z to 2012-03-22T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-03-23T00:00:00.000000Z to 2012-03-23T23:59:59.000000Z: list index out of range
# [##                                      ] | 5% Completed | 126.73 sFailed to get data from 2012-03-24T00:00:00.000000Z to 2012-03-24T00:16:40.000000Z: list index out of range
# [2012-03-22T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-08-28T23:43:20.000000Z to 2011-08-28T23:59:59.000000Z: list index out of rangeFailed to get data from 2009-09-07T23:43:20.000000Z to 2009-09-07T23:59:59.000000Z: list index out of range[2013-08-31T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
#
#
# Failed to get data from 2011-08-29T00:00:00.000000Z to 2011-08-29T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-30T00:00:00.000000Z to 2011-08-30T00:16:40.000000Z: list index out of rangeFailed to get data from 2009-09-08T00:00:00.000000Z to 2009-09-08T23:59:59.000000Z: list index out of range
# [2011-08-28T23:43:20.000000Z] No traces found in stream. Skipping.
#
# Failed to get data from 2009-09-09T00:00:00.000000Z to 2009-09-09T00:16:40.000000Z: list index out of range
# [2009-09-07T23:43:20.000000Z] No traces found in stream. Skipping.
# [2013-10-21T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# Failed to get data from 2011-07-07T23:43:20.000000Z to 2011-07-07T23:59:59.000000Z: list index out of range
# [##                                      ] | 5% Completed | 126.91 sFailed to get data from 2011-07-08T00:00:00.000000Z to 2011-07-08T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-07-09T00:00:00.000000Z to 2011-07-09T00:16:40.000000Z: list index out of range
# [2011-07-07T23:43:20.000000Z] No traces found in stream. Skipping.
# Failed to get data from 2011-02-03T23:43:20.000000Z to 2011-02-03T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-04-22T23:43:20.000000Z to 2011-04-22T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2011-02-04T00:00:00.000000Z to 2011-02-04T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-04-23T00:00:00.000000Z to 2011-04-23T23:59:59.000000Z: list index out of range
# [2014-03-06T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'Failed to get data from 2011-04-24T00:00:00.000000Z to 2011-04-24T00:16:40.000000Z: list index out of range
# [2011-04-22T23:43:20.000000Z] No traces found in stream. Skipping.
#
# [##                                      ] | 5% Completed | 127.02 sFailed to get data from 2012-02-22T23:43:20.000000Z to 2012-02-22T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-23T00:00:00.000000Z to 2012-02-23T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-02-24T00:00:00.000000Z to 2012-02-24T00:16:40.000000Z: list index out of range
# [2012-02-22T23:43:20.000000Z] No traces found in stream. Skipping.
# ...
# Failed to get data from 2010-03-28T00:00:00.000000Z to 2010-03-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-03-29T00:00:00.000000Z to 2010-03-29T00:16:40.000000Z: list index out of range
# [2010-03-27T23:43:20.000000Z] No traces found in stream. Skipping.
# [##########################              ] | 67% Completed | 22m 8s[2011-02-08T05:16:31.560000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##########################              ] | 67% Completed | 22m 11s[2014-08-09T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##########################              ] | 67% Completed | 22m 11s[2013-01-10T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [##########################              ] | 67% Completed | 22m 12sFailed to get data from 2010-04-20T23:43:20.000000Z to 2010-04-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-04-21T00:00:00.000000Z to 2010-04-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-04-22T00:00:00.000000Z to 2010-04-22T00:16:40.000000Z: list index out of range
# [2010-04-20T23:43:20.000000Z] No traces found in stream. Skipping.
# [##########################              ] | 67% Completed | 22m 12sFailed to get data from 2011-09-11T23:43:20.000000Z to 2011-09-11T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-12T00:00:00.000000Z to 2011-09-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-13T00:00:00.000000Z to 2011-09-13T00:16:40.000000Z: list index out of range
# [2011-09-11T23:43:20.000000Z] No traces found in stream. Skipping.
# [##########################              ] | 67% Completed | 22m 12sFailed to get data from 2010-08-31T23:43:20.000000Z to 2010-08-31T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-09-01T00:00:00.000000Z to 2010-09-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-09-02T00:00:00.000000Z to 2010-09-02T00:16:40.000000Z: list index out of range
# [2010-08-31T23:43:20.000000Z] No traces found in stream. Skipping.
# [##########################              ] | 67% Completed | 22m 12sFailed to get data from 2011-09-29T23:43:20.000000Z to 2011-09-29T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-06T23:43:20.000000Z to 2012-05-06T23:59:59.000000Z: list index out of rangeFailed to get data from 2011-09-30T00:00:00.000000Z to 2011-09-30T23:59:59.000000Z: list index out of range
#
# Failed to get data from 2012-05-07T00:00:00.000000Z to 2012-05-07T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-01T00:00:00.000000Z to 2011-10-01T00:16:40.000000Z: list index out of rangeFailed to get data from 2012-05-08T00:00:00.000000Z to 2012-05-08T00:16:40.000000Z: list index out of range
#
# [2011-09-29T23:43:20.000000Z] No traces found in stream. Skipping.[2012-05-06T23:43:20.000000Z] No traces found in stream. Skipping.
#
# [##########################              ] | 67% Completed | 22m 12sFailed to get data from 2011-10-09T23:43:20.000000Z to 2011-10-09T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-10T00:00:00.000000Z to 2011-10-10T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-11T00:00:00.000000Z to 2011-10-11T00:16:40.000000Z: list index out of range
# [2011-10-09T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 12sFailed to get data from 2011-01-25T23:43:20.000000Z to 2011-01-25T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-01-26T00:00:00.000000Z to 2011-01-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-01-27T00:00:00.000000Z to 2011-01-27T00:16:40.000000Z: list index out of range
# [2011-01-25T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 13sFailed to get data from 2011-07-30T23:43:20.000000Z to 2011-07-30T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-07-31T00:00:00.000000Z to 2011-07-31T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-08-01T00:00:00.000000Z to 2011-08-01T00:16:40.000000Z: list index out of range
# [2011-07-30T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 13sFailed to get data from 2012-05-18T23:43:20.000000Z to 2012-05-18T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-19T00:00:00.000000Z to 2012-05-19T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-05-20T00:00:00.000000Z to 2012-05-20T00:16:40.000000Z: list index out of range
# [2012-05-18T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 13sFailed to get data from 2010-11-01T23:43:20.000000Z to 2010-11-01T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-11-02T00:00:00.000000Z to 2010-11-02T23:59:59.000000Z: list index out of range
# [###########################             ] | 67% Completed | 22m 13sFailed to get data from 2010-11-03T00:00:00.000000Z to 2010-11-03T00:16:40.000000Z: list index out of range
# [2010-11-01T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 14sFailed to get data from 2010-04-13T23:43:20.000000Z to 2010-04-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-04-14T00:00:00.000000Z to 2010-04-14T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-04-15T00:00:00.000000Z to 2010-04-15T00:16:40.000000Z: list index out of range
# [2010-04-13T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 14sFailed to get data from 2011-09-20T23:43:20.000000Z to 2011-09-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-21T00:00:00.000000Z to 2011-09-21T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-09-22T00:00:00.000000Z to 2011-09-22T00:16:40.000000Z: list index out of range
# [2011-09-20T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 67% Completed | 22m 15s[2012-06-28T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 67% Completed | 22m 18s[2010-10-18T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 67% Completed | 22m 20s[2015-01-02T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 67% Completed | 22m 21s[2013-06-01T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 67% Completed | 22m 21sFailed to get data from 2011-10-14T23:43:20.000000Z to 2011-10-14T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-15T00:00:00.000000Z to 2011-10-15T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-10-16T00:00:00.000000Z to 2011-10-16T00:16:40.000000Z: list index out of range
# [2011-10-14T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 22sFailed to get data from 2011-03-28T23:43:20.000000Z to 2011-03-28T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-29T00:00:00.000000Z to 2011-03-29T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-30T00:00:00.000000Z to 2011-03-30T00:16:40.000000Z: list index out of range
# [2011-03-28T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 23s[2012-12-17T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 24s[2014-04-27T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 24sFailed to get data from 2010-01-22T23:43:20.000000Z to 2010-01-22T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-23T00:00:00.000000Z to 2010-01-23T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-24T00:00:00.000000Z to 2010-01-24T00:16:40.000000Z: list index out of range
# [2010-01-22T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 24sFailed to get data from 2012-11-28T23:43:20.000000Z to 2012-11-28T23:59:59.000000Z: list index out of range
# [###########################             ] | 68% Completed | 22m 25s[2012-12-21T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 27s[2014-06-26T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 28s[2012-09-04T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 28sFailed to get data from 2009-11-26T23:43:20.000000Z to 2009-11-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-11-27T00:00:00.000000Z to 2009-11-27T23:59:59.000000Z: list index out of range
# [###########################             ] | 68% Completed | 22m 28sFailed to get data from 2009-11-28T00:00:00.000000Z to 2009-11-28T00:16:40.000000Z: list index out of range
# [2009-11-26T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 34s[2013-04-26T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 35s[2014-07-17T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 35sFailed to get data from 2015-05-25T23:43:20.000000Z to 2015-05-25T23:59:59.000000Z: list index out of range
# [###########################             ] | 68% Completed | 22m 35sFailed to get data from 2015-05-26T00:00:00.000000Z to 2015-05-26T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-05-27T00:00:00.000000Z to 2015-05-27T00:16:40.000000Z: list index out of range
# [2015-05-25T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 36sFailed to get data from 2010-01-10T23:43:20.000000Z to 2010-01-10T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-11T00:00:00.000000Z to 2010-01-11T23:59:59.000000Z: list index out of range
# Failed to get data from 2010-01-12T00:00:00.000000Z to 2010-01-12T00:16:40.000000Z: list index out of range
# [2010-01-10T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 38s[2013-05-31T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [2012-10-12T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 39s[2012-10-17T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 39sFailed to get data from 2011-03-12T23:43:20.000000Z to 2011-03-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-13T00:00:00.000000Z to 2011-03-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2011-03-14T00:00:00.000000Z to 2011-03-14T00:16:40.000000Z: list index out of range
# [2011-03-12T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 40s[2010-10-24T01:15:27.720000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 40sFailed to get data from 2015-05-30T23:43:20.000000Z to 2015-05-30T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-05-31T00:00:00.000000Z to 2015-05-31T23:59:59.000000Z: list index out of range
# Failed to get data from 2015-06-01T00:00:00.000000Z to 2015-06-01T00:16:40.000000Z: list index out of range
# [2015-05-30T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 41sFailed to get data from 2014-03-25T00:00:00.000000Z to 2014-03-25T00:16:40.000000Z: list index out of range
# [###########################             ] | 68% Completed | 22m 41sn/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 68% Completed | 22m 41sFailed to get data from 2012-04-13T23:43:20.000000Z to 2012-04-13T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-04-14T00:00:00.000000Z to 2012-04-14T23:59:59.000000Z: list index out of range
# Failed to get data from 2012-04-15T00:00:00.000000Z to 2012-04-15T00:16:40.000000Z: list index out of range
# [2012-04-13T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 41sFailed to get data from 2009-12-19T23:43:20.000000Z to 2009-12-19T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-12-20T00:00:00.000000Z to 2009-12-20T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-12-21T00:00:00.000000Z to 2009-12-21T00:16:40.000000Z: list index out of range
# [2009-12-19T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 68% Completed | 22m 43s[2013-05-08T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 69% Completed | 22m 43sFailed to get data from 2009-09-11T23:43:20.000000Z to 2009-09-11T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-09-12T00:00:00.000000Z to 2009-09-12T23:59:59.000000Z: list index out of range
# Failed to get data from 2009-09-13T00:00:00.000000Z to 2009-09-13T00:16:40.000000Z: list index out of range
# [2009-09-11T23:43:20.000000Z] No traces found in stream. Skipping.
# [###########################             ] | 69% Completed | 22m 45s[2014-09-14T23:43:20.000000Z] No data or fatal error during detection/classification: gaussian_filter1d() got an unexpected keyword argument 'radius'
# [###########################             ] | 69% Completed | 22m 47s

# %% [markdown]
# ## Concat Results & Save

# %%
os.chdir('/home/lydiagk/obs_tremor/tremor_detection')
print("Current working directory:", os.getcwd())

# %%
# removing empty brackets
cleaned_results = [entry for entry in results if entry]
with open(pickle_path, 'wb') as f:
    pickle.dump(cleaned_results, f)

print(f"Saved combined detection results to {pickle_path}")
print(f"Total detections: {len(cleaned_results)}")
display(cleaned_results)

# %%
with open(pickle_path, 'rb') as f:
    raw_triggers = pickle.load(f)

flattened = [
    detection
    for day in raw_triggers
    if isinstance(day, list)
    for detection in day
    if detection and isinstance(detection, (list, tuple)) and len(detection) == 6]

with open('classifications/J09B.pickle', 'wb') as f:
    pickle.dump(flattened, f)

# %% [markdown]
# ## Checking my work against validated code

# %%
os.chdir("/home/lydiagk/obs_tremor/tremor_detection")


start_time = UTCDateTime("2017-09-01T00:00:00.000")
end_time = UTCDateTime("2017-09-08T00:00:00.000")


with open('flat_triggers.pickle', 'rb') as f:
    my_triggers = pickle.load(f)
   
count = sum(1 for entry in my_triggers if start_time <= entry[0][0] <= end_time)

print(f"Number of triggers between {start_time} and {end_time}: {count}")
starts = [entry[0][0] for entry in my_triggers if start_time <= entry[0][0] <= end_time]
peaks = [entry[2] for entry in my_triggers if start_time <= entry[0][0] <= end_time and entry[2] == 1]
print(len(peaks))
print(peaks)

# %%
os.chdir("/home/lydiagk/obs_tremor/tremor_detection/results")

# define time window
start_time_v = UTCDateTime("2017-09-01T00:00:00.000")
end_time_v = UTCDateTime("2017-09-08T00:00:00.000")

with open('HYSB1_HHN_3-10Hz_classifications.pickle', 'rb') as f:
    my_triggers_v = pickle.load(f)


count_v = sum(1 for entry in my_triggers_v if start_time_v <= entry[0][0] <= end_time_v)

print(f"Number of triggers between {start_time_v} and {end_time_v}: {count_v}")
starts_v = [entry[0][0] for entry in my_triggers_v if start_time_v <= entry[0][0] <= end_time_v]
peaks_v = [entry[2] for entry in my_triggers_v if start_time <= entry[0][0] <= end_time and entry[2] == 1]

print(len(peaks_v))
print(peaks_v)
